# %%
import numpy as np
import pandas as pd

# %%
salary=pd.read_csv(r'Desktop\Salarydata.csv')

# %%
salary
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
salary.tail() ### details of last 5 column
# Out:
#     YearsExperience  Salary
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
salary.head() ## details of first 5 column
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %% [markdown]
# ### superstore exploratory analysis

# %% [markdown]
# #### importing library

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### reading the data

# %%
d=pd.read_excel('superstore.xls')

# %%
d
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %% [markdown]
# ### check the size

# %%
d.shape
# Out:
# (9994, 21)

# %% [markdown]
# ### check data type of attributes

# %%
d.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %% [markdown]
# #### to check there is any missing value

# %% [markdown]
# d.isnull()

# %%
d.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# ### total number of null values in a dataset

# %%
d.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# #### to print first 5 recors

# %%
d.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
d.head(10) ###showing first 10 box
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5       6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6       7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7       8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8       9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9      10  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# ...

# %% [markdown]
# #### to print bottom 5 records

# %%
d.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
d.tail(10) ###it print last 10 records
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9984    9985  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9985    9986  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9986    9987  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 9987    9988  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9988    9989  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country         City  \
# 9984    DV-13465  Dianna Vittorini   Consumer  United States   Long Beach
# 9985    DV-13465  Dianna Vittorini   Consumer  United States   Long Beach
# ...

# %% [markdown]
# #### print information of dataset

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# #### drop the columns which not required

# %%
d
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
d.drop(['Row ID'],axis=1,inplace=True)
d ##inplace used to permenant change
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2     CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2014-110422 2014-01-21 2014-01-23    Second Class    TB-21400
# 9990  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9993  CA-2017-119914 2017-05-04 2017-05-09    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
d.drop(['Postal Code'],axis=1,inplace=True)
d
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2     CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2014-110422 2014-01-21 2014-01-23    Second Class    TB-21400
# 9990  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9993  CA-2017-119914 2017-05-04 2017-05-09    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
d.drop(['Order Date','Order ID','Customer ID','Product ID'],axis=1,inplace=True)
d
# Out:
#       Ship Date       Ship Mode     Customer Name    Segment        Country  \
# 0    2016-11-11    Second Class       Claire Gute   Consumer  United States
# 1    2016-11-11    Second Class       Claire Gute   Consumer  United States
# 2    2016-06-16    Second Class   Darrin Van Huff  Corporate  United States
# 3    2015-10-18  Standard Class    Sean O'Donnell   Consumer  United States
# 4    2015-10-18  Standard Class    Sean O'Donnell   Consumer  United States
# ...         ...             ...               ...        ...            ...
# 9989 2014-01-23    Second Class  Tom Boeckenhauer   Consumer  United States
# 9990 2017-03-03  Standard Class       Dave Brooks   Consumer  United States
# 9991 2017-03-03  Standard Class       Dave Brooks   Consumer  United States
# 9992 2017-03-03  Standard Class       Dave Brooks   Consumer  United States
# 9993 2017-05-09    Second Class      Chris Cortes   Consumer  United States
#
# ...

# %%
d.drop(['Ship Date','Product Name'],axis=1,inplace=True)
d
# Out:
#            Ship Mode     Customer Name    Segment        Country  \
# 0       Second Class       Claire Gute   Consumer  United States
# 1       Second Class       Claire Gute   Consumer  United States
# 2       Second Class   Darrin Van Huff  Corporate  United States
# 3     Standard Class    Sean O'Donnell   Consumer  United States
# 4     Standard Class    Sean O'Donnell   Consumer  United States
# ...              ...               ...        ...            ...
# 9989    Second Class  Tom Boeckenhauer   Consumer  United States
# 9990  Standard Class       Dave Brooks   Consumer  United States
# 9991  Standard Class       Dave Brooks   Consumer  United States
# 9992  Standard Class       Dave Brooks   Consumer  United States
# 9993    Second Class      Chris Cortes   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
d.shape
# Out:
# (9994, 14)

# %%
d
# Out:
#            Ship Mode     Customer Name    Segment        Country  \
# 0       Second Class       Claire Gute   Consumer  United States
# 1       Second Class       Claire Gute   Consumer  United States
# 2       Second Class   Darrin Van Huff  Corporate  United States
# 3     Standard Class    Sean O'Donnell   Consumer  United States
# 4     Standard Class    Sean O'Donnell   Consumer  United States
# ...              ...               ...        ...            ...
# 9989    Second Class  Tom Boeckenhauer   Consumer  United States
# 9990  Standard Class       Dave Brooks   Consumer  United States
# 9991  Standard Class       Dave Brooks   Consumer  United States
# 9992  Standard Class       Dave Brooks   Consumer  United States
# 9993    Second Class      Chris Cortes   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %% [markdown]
# ### to print the statistic informations

# %%
d.describe() ### describe the quantitative dta
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
d.describe(include="all")
# Out:
#              Ship Mode  Customer Name   Segment        Country           City  \
# count             9994           9994      9994           9994           9994
# unique               4            793         3              1            531
# top     Standard Class  William Brown  Consumer  United States  New York City
# freq              5968             37      5191           9994            915
# mean               NaN            NaN       NaN            NaN            NaN
# std                NaN            NaN       NaN            NaN            NaN
# min                NaN            NaN       NaN            NaN            NaN
# 25%                NaN            NaN       NaN            NaN            NaN
# 50%                NaN            NaN       NaN            NaN            NaN
# 75%                NaN            NaN       NaN            NaN            NaN
# max                NaN            NaN       NaN            NaN            NaN
#
# ...

# %% [markdown]
# ### to check any duplicate value

# %%
d.duplicated().sum()
# Out:
# 2

# %%
d=d.drop_duplicates()

# %%
d
# Out:
#            Ship Mode     Customer Name    Segment        Country  \
# 0       Second Class       Claire Gute   Consumer  United States
# 1       Second Class       Claire Gute   Consumer  United States
# 2       Second Class   Darrin Van Huff  Corporate  United States
# 3     Standard Class    Sean O'Donnell   Consumer  United States
# 4     Standard Class    Sean O'Donnell   Consumer  United States
# ...              ...               ...        ...            ...
# 9989    Second Class  Tom Boeckenhauer   Consumer  United States
# 9990  Standard Class       Dave Brooks   Consumer  United States
# 9991  Standard Class       Dave Brooks   Consumer  United States
# 9992  Standard Class       Dave Brooks   Consumer  United States
# 9993    Second Class      Chris Cortes   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %% [markdown]
# #### rename column name

# %%
d.rename(columns={"Country/Region":"Country"},inplace=True)

# %%
d
# Out:
#            Ship Mode     Customer Name    Segment        Country  \
# 0       Second Class       Claire Gute   Consumer  United States
# 1       Second Class       Claire Gute   Consumer  United States
# 2       Second Class   Darrin Van Huff  Corporate  United States
# 3     Standard Class    Sean O'Donnell   Consumer  United States
# 4     Standard Class    Sean O'Donnell   Consumer  United States
# ...              ...               ...        ...            ...
# 9989    Second Class  Tom Boeckenhauer   Consumer  United States
# 9990  Standard Class       Dave Brooks   Consumer  United States
# 9991  Standard Class       Dave Brooks   Consumer  United States
# 9992  Standard Class       Dave Brooks   Consumer  United States
# 9993    Second Class      Chris Cortes   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
d=d.drop(['Order ID'],axis=1) ### INSTEAD OF INPLACE U CAN USE LIKE THIS
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 d=d.drop(['Order ID'],axis=1)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
# ...

# %% [markdown]
# ### print some randome line

# %%
d.sample(4)
# Out:
#          Ship Mode    Customer Name    Segment        Country           City  \
# 71    Second Class  Tracy Blumstein   Consumer  United States        Jackson
# 1584   First Class     Naresj Patel   Consumer  United States  New York City
# 4887  Second Class   Randy Ferguson  Corporate  United States       Marietta
# 1853  Second Class    Ralph Kennedy   Consumer  United States     South Bend
#
#          State  Postal Code   Region         Category Sub-Category   Sales  \
# 71    Michigan        49201  Central  Office Supplies        Paper   19.05
# 1584  New York        10024     East        Furniture  Furnishings    6.16
# 4887   Georgia        30062    South       Technology  Accessories  101.70
# 1853   Indiana        46614  Central  Office Supplies        Paper   97.82
#
#       Quantity  Discount   Profit
# 71           3       0.0   8.7630
# 1584         2       0.0   2.9568
# 4887         6       0.0   6.1020
# 1853         2       0.0  45.9754

# %%
d.nunique() ### checking unique value here shipe mode
# Out:
# Ship Mode           4
# Customer Name     793
# Segment             3
# Country             1
# City              531
# State              49
# Postal Code       631
# Region              4
# Category            3
# Sub-Category       17
# Sales            6144
# Quantity           14
# Discount           12
# Profit           7545
# dtype: int64

# %%
d.corr() ### correlation range btwn -1 and 1.if -ve no highly correlation
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023813  0.012721  0.058569 -0.029962
# Sales          -0.023813  1.000000  0.200812 -0.028222  0.479067
# Quantity        0.012721  0.200812  1.000000  0.008687  0.066242
# Discount        0.058569 -0.028222  0.008687  1.000000 -0.219493
# Profit         -0.029962  0.479067  0.066242 -0.219493  1.000000

# %%
d.cov() ##both +ve both increase one +ve one _ve it is one increase one decrease
# Out:
#               Postal Code          Sales    Quantity    Discount  \
# Postal Code  1.028120e+09 -475921.795591  907.636092  387.728678
# Sales       -4.759218e+05  388507.783522  278.529185   -3.631884
# Quantity     9.076361e+02     278.529185    4.951779    0.003991
# Discount     3.877287e+02      -3.631884    0.003991    0.042626
# Profit      -2.250764e+05   69957.976862   34.534730  -10.616965
#
#                     Profit
# Postal Code -225076.443596
# Sales         69957.976862
# Quantity         34.534730
# Discount        -10.616965
# Profit        54888.591226

# %%
d=pd.read_excel('superstore.xls')

# %%
d
# Out:
#            Ship Mode     Customer Name    Segment        Country  \
# 0       Second Class       Claire Gute   Consumer  United States
# 1       Second Class       Claire Gute   Consumer  United States
# 2       Second Class   Darrin Van Huff  Corporate  United States
# 3     Standard Class    Sean O'Donnell   Consumer  United States
# 4     Standard Class    Sean O'Donnell   Consumer  United States
# ...              ...               ...        ...            ...
# 9989    Second Class  Tom Boeckenhauer   Consumer  United States
# 9990  Standard Class       Dave Brooks   Consumer  United States
# 9991  Standard Class       Dave Brooks   Consumer  United States
# 9992  Standard Class       Dave Brooks   Consumer  United States
# 9993    Second Class      Chris Cortes   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %% [markdown]
# ### atatistic figures

# %%
d['Sales'].count()
# Out:
# 9992

# %%
d['Sales'].mean()
# Out:
# 229.873255434343

# %%
d['Sales'].max()
# Out:
# 22638.48

# %%
d['Sales'].min()
# Out:
# 0.44399999999999995

# %%
d['Sales'].std()
# Out:
# 623.3039254825736

# %% [markdown]
# ### categories

# %%
d['Category'].value_counts()
# Out:
# Office Supplies    6025
# Furniture          2120
# Technology         1847
# Name: Category, dtype: int64

# %%
d['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
d['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
d['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
d['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
d1=d.copy()
d1=d1.pivot_table('Profit',columns='Region',aggfunc='sum')
d1
# Out:
# Region     Central        East       South         West
# Profit  39706.3625  91534.8388  46749.4303  108406.0073

# %%
d2=d.copy()
d2=d2.pivot_table('Sales',columns='Region',aggfunc='max')
d2
# Out:
# Region   Central       East     South      West
# Sales   17499.95  11199.968  22638.48  13999.96

# %%
d4=d.copy()
d4
# Out:
#            Ship Mode     Customer Name    Segment        Country  \
# 0       Second Class       Claire Gute   Consumer  United States
# 1       Second Class       Claire Gute   Consumer  United States
# 2       Second Class   Darrin Van Huff  Corporate  United States
# 3     Standard Class    Sean O'Donnell   Consumer  United States
# 4     Standard Class    Sean O'Donnell   Consumer  United States
# ...              ...               ...        ...            ...
# 9989    Second Class  Tom Boeckenhauer   Consumer  United States
# 9990  Standard Class       Dave Brooks   Consumer  United States
# 9991  Standard Class       Dave Brooks   Consumer  United States
# 9992  Standard Class       Dave Brooks   Consumer  United States
# 9993    Second Class      Chris Cortes   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
d4['Sales']=d['Sales']*d['Quantity']
d4['Sales']
# Out:
# 0        523.9200
# 1       2195.8200
# 2         29.2400
# 3       4787.8875
# 4         44.7360
#           ...
# 9989      75.7440
# 9990     183.9200
# 9991     517.1520
# 9992     118.4000
# 9993     486.3200
# Name: Sales, Length: 9992, dtype: float64

# %%
d4
# Out:
#            Ship Mode     Customer Name    Segment        Country  \
# 0       Second Class       Claire Gute   Consumer  United States
# 1       Second Class       Claire Gute   Consumer  United States
# 2       Second Class   Darrin Van Huff  Corporate  United States
# 3     Standard Class    Sean O'Donnell   Consumer  United States
# 4     Standard Class    Sean O'Donnell   Consumer  United States
# ...              ...               ...        ...            ...
# 9989    Second Class  Tom Boeckenhauer   Consumer  United States
# 9990  Standard Class       Dave Brooks   Consumer  United States
# 9991  Standard Class       Dave Brooks   Consumer  United States
# 9992  Standard Class       Dave Brooks   Consumer  United States
# 9993    Second Class      Chris Cortes   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
d4=d4.groupby(['Category'])['Sales'].sum() ##groupby category printing sum of sales in the form of data frame
d4=pd.DataFrame(d4)
d4
# Out:
#                         Sales
# Category
# Furniture        3.858652e+06
# Office Supplies  3.548482e+06
# Technology       4.080262e+06

# %%
n=d.groupby('Category').Sales.sum().sort_values(ascending=False)##groupby the categor and printing sum of sales in descending orde
n
# Out:
# Category
# Technology         836154.0330
# Furniture          741718.4233
# Office Supplies    719021.1120
# Name: Sales, dtype: float64

# %%
n=d.groupby('Sub-Category').Sales.sum().sort_values(ascending=False)
n
# Out:
# Sub-Category
# Phones         330007.0540
# Chairs         328167.7310
# Storage        223843.6080
# Tables         206965.5320
# Binders        203412.7330
# Machines       189238.6310
# Accessories    167380.3180
# Copiers        149528.0300
# Bookcases      114879.9963
# Appliances     107532.1610
# Furnishings     91705.1640
# Paper           78453.2860
# Supplies        46673.5380
# Art             27118.7920
# Envelopes       16476.4020
# Labels          12486.3120
# Fasteners        3024.2800
# Name: Sales, dtype: float64

# %%
n.head()
# Out:
# Sub-Category
# Phones     330007.054
# Chairs     328167.731
# Storage    223843.608
# Tables     206965.532
# Binders    203412.733
# Name: Sales, dtype: float64

# %%
pd.crosstab(d['Segment'],d['Region']) ## creating a crosstab
# Out:
# Region       Central  East  South  West
# Segment
# Consumer        1212  1469    838  1671
# Corporate        673   877    510   960
# Home Office      438   501    272   571

# %%
d.sort_values(by=['Category'])
# Out:
#            Ship Mode    Customer Name      Segment        Country  \
# 0       Second Class      Claire Gute     Consumer  United States
# 8133  Standard Class        Gene Hale    Corporate  United States
# 1903     First Class  Damala Kotsonis    Corporate  United States
# 6150     First Class    Raymond Messe     Consumer  United States
# 6151    Second Class    Eileen Kiefer  Home Office  United States
# ...              ...              ...          ...            ...
# 5922  Standard Class     Peter Fuller     Consumer  United States
# 8594  Standard Class      Peter McVee  Home Office  United States
# 8593  Standard Class      Peter McVee  Home Office  United States
# 3505  Standard Class       Sam Craven     Consumer  United States
# 3142    Second Class     Raymond Buch     Consumer  United States
#
#                City       State  Postal Code   Region    Category  \
# 0         Henderson    Kentucky        42420    South   Furniture
# ...

# %%
grouped=pd.DataFrame(d.groupby(['Ship Mode','Category','Sub-Category','State','Region'])['Quantity','Discount','Sales','Profit'].sum().reset_index())
grouped
# Out:
#            Ship Mode    Category Sub-Category        State   Region  Quantity  \
# 0        First Class   Furniture    Bookcases      Arizona     West        12
# 1        First Class   Furniture    Bookcases   California     West        47
# 2        First Class   Furniture    Bookcases     Colorado     West         6
# 3        First Class   Furniture    Bookcases  Connecticut     East         9
# 4        First Class   Furniture    Bookcases      Florida    South         3
# ...              ...         ...          ...          ...      ...       ...
# 1629  Standard Class  Technology       Phones         Utah     West         3
# 1630  Standard Class  Technology       Phones      Vermont     East         5
# 1631  Standard Class  Technology       Phones     Virginia    South        54
# 1632  Standard Class  Technology       Phones   Washington     West        66
# 1633  Standard Class  Technology       Phones    Wisconsin  Central        33
#
# ...

# %%
d_shipmode=d[['Ship Mode','Category','Quantity']].groupby(['Ship Mode','Category']).sum('Quantity')
d_shipmode
# Out:
#                                 Quantity
# Ship Mode      Category
# First Class    Furniture            1238
#                Office Supplies      3372
#                Technology           1083
# Same Day       Furniture             453
#                Office Supplies      1147
#                Technology            360
# Second Class   Furniture            1569
#                Office Supplies      4480
#                Technology           1374
# Standard Class Furniture            4766
#                Office Supplies     13903
#                Technology           4122

# %%
state_sales_d=pd.pivot_table(data=d[['State','Sales']],index=['State'],values='Sales',aggfunc='max')

# %%
state_sales_d
# Out:
#                           Sales
# State
# Alabama                3040.000
# Arizona                1879.960
# Arkansas               1793.980
# California             8187.650
# Colorado               2549.985
# Connecticut            1133.350
# Delaware              10499.970
# District of Columbia   1379.920
# Florida               22638.480
# Georgia                6354.950
# Idaho                  1128.390
# Illinois               2799.960
# Indiana               17499.950
# Iowa                   1408.100
# Kansas                  360.380
# Kentucky               3080.000
# Louisiana              1665.620
# Maine                   437.850
# Maryland               2541.980
# Massachusetts          1737.180
# Michigan               9892.740
# Minnesota              9449.950
# Mississippi            2430.080
# Missouri               4899.930
# Montana                2999.950
# Nebraska               2479.960
# Nevada                 4535.976
# New Hampshire          2249.910
# ...

# %%
state_sales_d.sort_values(by="Sales",ascending=False).head(10)
# Out:
#                   Sales
# State
# Florida       22638.480
# Indiana       17499.950
# Washington    13999.960
# New York      11199.968
# Delaware      10499.970
# Michigan       9892.740
# Minnesota      9449.950
# New Jersey     9099.930
# Virginia       8749.950
# Pennsylvania   8399.976

# %%
state_profit_d=pd.pivot_table(data=d[['State','Profit']],
                            index=['State'],
                            values='Profit',
                            aggfunc='max')

state_profit_d.sort_values(by='Profit',ascending=False).head(10)
# Out:
#                  Profit
# State
# Indiana       8399.9760
# Washington    6719.9808
# Delaware      5039.9856
# Michigan      4946.3700
# Minnesota     4630.4755
# New York      3919.9888
# Georgia       3177.4750
# Virginia      2799.9840
# Rhode Island  2591.9568
# New Jersey    2365.9818

# %%
d_Category_sales=pd.pivot_table(data=d[['Category','Sub-Category','Sales']],index=['Category','Sub-Category'],values='Sales',aggfunc="max")
d_Category_sales
# Out:
#                                   Sales
# Category        Sub-Category
# Furniture       Bookcases      4404.900
#                 Chairs         4416.174
#                 Furnishings    1336.440
#                 Tables         4297.644
# Office Supplies Appliances     2625.120
#                 Art            1113.024
#                 Binders        9892.740
#                 Envelopes       604.656
#                 Fasteners        93.360
#                 Labels          786.480
#                 Paper           733.950
#                 Storage        2934.330
#                 Supplies       8187.650
# Technology      Accessories    3347.370
#                 Copiers       17499.950
#                 Machines      22638.480
#                 Phones         4548.810

# %%
d_Category_quantity=pd.pivot_table(data=d[['Category','Sub-Category','Quantity']],
                            index=['Category','Sub-Category'],
                            values='Quantity',
                            aggfunc='sum')

d_Category_quantity
# Out:
#                               Quantity
# Category        Sub-Category
# Furniture       Bookcases          868
#                 Chairs            2354
#                 Furnishings       3563
#                 Tables            1241
# Office Supplies Appliances        1729
#                 Art               3000
#                 Binders           5974
#                 Envelopes          906
#                 Fasteners          914
#                 Labels            1400
#                 Paper             5174
#                 Storage           3158
#                 Supplies           647
# Technology      Accessories       2976
#                 Copiers            234
#                 Machines           440
#                 Phones            3289

# %%
d_Category_quantity=pd.pivot_table(data=d[['Category','Sub-Category','Quantity']],
                            index=['Category','Sub-Category'],
                            values='Quantity',
                            aggfunc='sum')

d_Category_quantity
# Out:
#                               Quantity
# Category        Sub-Category
# Furniture       Bookcases          868
#                 Chairs            2356
#                 Furnishings       3563
#                 Tables            1241
# Office Supplies Appliances        1729
#                 Art               3000
#                 Binders           5974
#                 Envelopes          906
#                 Fasteners          914
#                 Labels            1400
#                 Paper             5178
#                 Storage           3158
#                 Supplies           647
# Technology      Accessories       2976
#                 Copiers            234
#                 Machines           440
#                 Phones            3289

# %%
d['Revenue']=d['Sales']-d['Profit'] ## new column revenue is added

# %%
d
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
d=pd.read_excel('superstore.xls')

# %%
d
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
d['Grossprice']=(d['Revenue']-d['Profit'])/d['Quantity']

# %%
d.head(10)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5       6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6       7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7       8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8       9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9      10  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# ...

# %% [markdown]
# ### data visualization

# %% [markdown]
# ### PLOT GRAPH PROFIT VS QUANTITY

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(d['Quantity'],d["Profit"])
plt.title("Profit vs Quantity",fontsize=15,color="red")
plt.xlabel("Quantity",fontsize=15)
plt.ylabel("Profit",fontsize=15)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(18,5))
plt.bar('Sub-Category','Category',data=d,color='orange')
plt.show()

# %%
print(d['State'].value_counts())
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(15,4))
sns.countplot(x=d["State"])
plt.xticks(rotation=90)
plt.show()

# %%
print(d["Sub-Category"].value_counts())
plt.figure(figsize=(10,6))
sns.countplot(x=d["Sub-Category"])
plt.xticks(rotation=90)
plt.show()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64
